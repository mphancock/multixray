# %%
import pandas as pd 
from pathlib import Path

# %%
exp_dir = Path(Path.home(), "Documents/xray/sample_bench/single_state/likelihood_weight/non_equil_single_state_noisy")
log_file = Path(exp_dir, "output_4/log.csv")

pd.read_csv(log_file)
# Out:
#       Unnamed: 0  step         time          ff      xray       df_mag  \
# 0              0     0     1.765425  271.273236  3.000536  7939.119207
# 1              1     1     2.667615  346.422650  2.996749  6088.253318
# 2              2     2     3.564830  395.680552  2.988907  4418.037162
# 3              3     3     4.454371  384.913000  2.976490  5776.722351
# 4              4     4     5.325927  340.076849  2.959773  7671.813825
# ...          ...   ...          ...         ...       ...          ...
# 2495        2495  2495  2167.655043  280.172656  2.074008  6872.681695
# 2496        2496  2496  2168.362785  282.389011  2.071946  7071.392470
# 2497        2497  2497  2169.066948  267.389951  2.072260  6680.273781
# 2498        2498  2498  2169.774722  263.505748  2.072569  6397.968250
# 2499        2499  2499  2170.478636  277.360591  2.072422  6440.946006
#
#           RMSD  M2 SD dff dx  M2 SD dxray dx
# 0     0.342550      6.970170       -0.001527
# ...
