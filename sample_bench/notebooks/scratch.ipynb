# %%
from pathlib import Path 
import pickle

# %%
with open(Path(Path.home(), "Documents/xray/sample_bench/data/groups/m_n_1000/1000.pl"), 'rb') as f:
    x = pickle.load(f)

# %%
x[0]
# Out:
# [593,
#  721,
#  663,
#  253,
#  634,
#  950,
#  684,
#  454,
#  64,
#  414,
#  766,
#  973,
#  828,
#  83,
#  927,
#  341,
#  69,
#  702,
#  284,
#  946,
#  683,
#  697,
#  329,
#  31,
#  798,
#  446,
#  553,
#  735,
#  234,
#  28,
#  395,
#  485,
#  365,
#  731,
#  592,
#  892,
#  590,
#  400,
#  122,
#  796,
#  115,
#  270,
#  91,
#  152,
#  420,
#  73,
#  727,
#  587,
#  409,
#  960,
#  980,
#  586,
#  811,
#  237,
#  200,
#  298,
#  821,
#  897,
#  674,
#  994,
#  511,
#  583,
#  155,
#  413,
#  879,
#  332,
#  870,
#  49,
#  981,
#  843,
#  140,
#  108,
#  930,
#  79,
#  250,
#  50,
#  42,
#  198,
#  569,
#  289,
#  403,
#  881,
#  871,
#  172,
#  746,
#  374,
#  240,
#  481,
#  678,
#  135,
#  971,
#  4,
#  352,
#  74,
#  327,
#  918,
#  383,
#  752,
#  719,
#  680,
#  690,
#  232,
#  324,
#  391,
#  494,
#  85,
#  974,
#  110,
#  668,
#  320,
#  385,
#  343,
#  190,
#  538,
#  54,
#  549,
#  415,
#  528,
#  645,
#  667,
#  175,
#  754,
#  502,
#  458,
#  877,
#  239,
#  493,
# ...
