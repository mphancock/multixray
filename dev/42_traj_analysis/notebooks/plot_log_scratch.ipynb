# %%
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
import matplotlib.colors as mcolors

# %%
log_file = Path(Path.home(), "Documents/xray/tmp/test/output_0/log.csv")
log_df = pd.read_csv(log_file, index_col=0)
print(log_df.columns)
log_df.head()
# Out:
# Index(['step', 'time', 'ff', 'xray_3k0m', 'r_free_3k0m', 'r_work_3k0m',
#        'w_0_3k0m', 'w_1_3k0m', 'w_2_3k0m', 'w_3_3k0m', 'pdb', 'copy',
#        'xyz_0_0', 'xyz_0_1', 'xyz_0_2', 'dxyz_0_0', 'dxyz_0_1', 'dxyz_0_2',
#        'd3k0m_dx_0_0', 'd3k0m_dx_0_1', 'd3k0m_dx_0_2', 'xyz_1_0', 'xyz_1_1',
#        'xyz_1_2', 'dxyz_1_0', 'dxyz_1_1', 'dxyz_1_2', 'd3k0m_dx_1_0',
#        'd3k0m_dx_1_1', 'd3k0m_dx_1_2', 'xyz_2_0', 'xyz_2_1', 'xyz_2_2',
#        'dxyz_2_0', 'dxyz_2_1', 'dxyz_2_2', 'd3k0m_dx_2_0', 'd3k0m_dx_2_1',
#        'd3k0m_dx_2_2', 'xyz_3_0', 'xyz_3_1', 'xyz_3_2', 'dxyz_3_0', 'dxyz_3_1',
#        'dxyz_3_2', 'd3k0m_dx_3_0', 'd3k0m_dx_3_1', 'd3k0m_dx_3_2', 'vel_mag',
#        'dcharmm_mag', 'dxray_3k0m_mag', 'rmsd_0', 'rmsd_1', 'rmsd_2', 'rmsd_3',
#        'temp'],
#       dtype='object')
#    step          time           ff  xray_3k0m  r_free_3k0m  r_work_3k0m  \
# 0   0.0  9.536743e-07  -826.334357   4.713699     0.338011     0.344608
# ...

# %%
colors = ["red", "blue", "green", "orange"]
for i in range(4):
    plt.plot(log_df["step"], log_df["d3k0m_dx_{}_0".format(i)], c=colors[i])

# %%
colors = ["red", "blue", "green", "orange"]
for i in range(4):
    plt.plot(log_df["step"], log_df["d3k0m_dx_{}_1".format(i)], c=colors[i])

# %%
colors = ["red", "blue", "green", "orange"]
for i in range(4):
    plt.plot(log_df["step"], log_df["d3k0m_dx_{}_2".format(i)], c=colors[i])

# %%
colors = ["red", "blue", "green", "orange"]
for i in range(4):
    plt.plot(log_df["step"], log_df["rmsd_{}".format(i)], c=colors[i])
