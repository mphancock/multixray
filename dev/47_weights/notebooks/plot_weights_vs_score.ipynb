# %%
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt

# %%
decoy_df = pd.read_csv("../../../sample_bench/data/analysis/267_full_ref/all_outs_1_score.csv", index_col=0)
decoy_df.head()
# Out:
#              ff  rmsd_native_0  \
# 0  12303.530454       0.115023
# 1  23284.674760       0.338546
# 2  29419.221242       0.705190
# 3  11026.297706       0.088417
# 4  26511.557446       1.518704
#
#                                                  pdb  w_0_native_0  \
# 0  /wynton/group/sali/mhancock/xray/sample_bench/...      0.558271
# 1  /wynton/group/sali/mhancock/xray/sample_bench/...      0.707335
# 2  /wynton/group/sali/mhancock/xray/sample_bench/...      0.979992
# 3  /wynton/group/sali/mhancock/xray/sample_bench/...      0.480960
# 4  /wynton/group/sali/mhancock/xray/sample_bench/...      0.185788
#
#    xray_native_0  w_1_native_0  r_free_native_0      rmsd  r_work_native_0  \
# 0       3.890983      0.441729         0.153537  0.115023         0.132815
# 1       4.218527      0.292665         0.220636  0.338546         0.190384
# 2       4.161332      0.020008         0.223772  0.705190         0.190562
# ...

# %%
plt.figure(figsize=(10,10))
plt.scatter(decoy_df["w_err"],decoy_df["xray_native_0"], c="black", s=10)

# plt.ylim(1,11)
# plt.xlim(-.1,1.1)
plt.tick_params(axis='both', which='major', labelsize=20)  # Adjust the size as needed

plt.savefig(Path(Path.home(), "Desktop/score_rmsd.png"))
