# %%
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt

# %%
decoy_df = pd.read_csv("../data/270_1_0.csv", index_col=0)
decoy_df.head()
# Out:
#    step          time            ff  xray_native_0  r_free_native_0  \
# 0   0.0  2.384186e-07  16555.191655       4.722941         0.274627
# 1   1.0  3.229230e+00  12517.636296       4.721122         0.274526
# 2   2.0  4.872406e+00   5961.215664       4.718282         0.274958
# 3   3.0  6.368431e+00   5073.546966       4.715044         0.275099
# 4   4.0  7.857615e+00  11263.881174       4.712289         0.276112
#
#    r_work_native_0      rmsd  w_0_native_0  w_1_native_0  \
# 0         0.284985  0.185363           0.9           0.1
# 1         0.284199  0.186891           0.9           0.1
# 2         0.283378  0.188818           0.9           0.1
# 3         0.282300  0.190968           0.9           0.1
# 4         0.281572  0.192821           0.9           0.1
#
#                                                  pdb  copy   vel_mag  \
# 0  /wynton/group/sali/mhancock/xray/sample_bench/...   1.0  0.000000
# 1                                                NaN   0.0  0.027320
# ...

# %%
plt.figure(figsize=(10,10))
plt.plot(decoy_df["step"],decoy_df["dxray_native_0_mag_0"], c="black")
plt.plot(decoy_df["step"],decoy_df["dxray_native_0_mag_1"], c="black")
plt.tick_params(axis='both', which='major', labelsize=20)  # Adjust the size as needed

plt.savefig(Path(Path.home(), "Desktop/df_mag.png"))
