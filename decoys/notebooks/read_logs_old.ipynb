# %%
import pickle
import pandas as pd
from pathlib import Path

# %%
log_file = Path(Path.home(), "Documents/xray/md_xray/4n7f_100k/output_0/md.log")
pd.read_pickle(log_file)
# Out:
# {0: [49.29128801610491,
#   90.75322911768599,
#   139.9190601249554,
#   29.487849583314606,
#   -1368.6036185965456,
#   -111.8083770199163],
#  10: [43.37091567416565,
#   76.61041983200721,
#   141.04706288370363,
#   15.827235347000546,
#   -1494.530589458788,
#   -113.81539864953658],
#  20: [31.20889318829097,
#   74.46674221733039,
#   143.38272022945344,
#   29.124210650244105,
#   -1637.1979319242325,
#   -112.32893902457619],
#  30: [25.107890363827554,
#   88.11917391282847,
#   143.2576358675287,
#   23.42283227020247,
#   -1767.0225165989384,
#   -110.28684208303741],
#  40: [25.38250442683731,
#   95.43662960234073,
#   143.29074861673328,
#   17.840591162768185,
#   -1866.8773305907466,
#   -108.36532679806477],
#  50: [26.83923534398745,
#   103.43221643943913,
#   144.50785827991382,
#   19.99495952866896,
#   -1958.2155428744684,
#   -108.01495148038731],
#  60: [24.00376322483306,
#   112.47304871366252,
#   145.77907450749217,
#   24.940081069441543,
# ...
